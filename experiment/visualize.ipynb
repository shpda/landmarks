# %% [markdown]
# **Visualize Experimental Results**

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import csv
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def printLossCurve(file):
    with open(file) as csvfile:
        readCSV = csv.reader(csvfile, delimiter=',')
        itrList = []
        lossList = []
        for row in readCSV:
            itrList.append(row[0])
            lossList.append(row[1])
        plt.plot(lossList)
        plt.show()

# %%
printLossCurve('/home/gangwu/projects/landmarks/experiment/unknown/train.csv')
